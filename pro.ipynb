# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, classification_report
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X_train = pd.read_csv('arcene_train.data', delim_whitespace=True, header=None)
y_train = pd.read_csv('arcene_train.labels', delim_whitespace=True, header=None)
X_valid = pd.read_csv('arcene_valid.data', delim_whitespace=True, header=None)

print("Training data shape:", X_train.shape)
print("Validation data shape:", X_valid.shape)
# Out:
# C:\Users\manos\AppData\Local\Temp\ipykernel_14200\1101313674.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   X_train = pd.read_csv('arcene_train.data', delim_whitespace=True, header=None)
# C:\Users\manos\AppData\Local\Temp\ipykernel_14200\1101313674.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   y_train = pd.read_csv('arcene_train.labels', delim_whitespace=True, header=None)
# C:\Users\manos\AppData\Local\Temp\ipykernel_14200\1101313674.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   X_valid = pd.read_csv('arcene_valid.data', delim_whitespace=True, header=None)
# Training data shape: (100, 10000)
# Validation data shape: (100, 10000)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_valid_scaled = scaler.transform(X_valid)

# %%
pca = PCA(n_components=50)
X_train_pca = pca.fit_transform(X_train_scaled)
X_valid_pca = pca.transform(X_valid_scaled)

# %%
plt.figure(figsize=(8,5))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('PCA - Explained Variance on Arcene Dataset')
plt.grid(True)
plt.show()

# %%
print("Reduced training data shape:", X_train_pca.shape)
# Out:
# Reduced training data shape: (100, 50)
